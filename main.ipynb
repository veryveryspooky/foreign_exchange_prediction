# %%
import numpy as np
import pandas as pd
from fredapi import Fred
import matplotlib.pyplot as plt
from hmmlearn import hmm

# %% [markdown]
# ## Read data downloaded from Bloomberg Terminal

# %%
usd_jpy = pd.read_excel('ExchangeRates.xlsx', sheet_name='usd-jpy')
usd_gbp = pd.read_excel('ExchangeRates.xlsx', sheet_name='usd-gbp')
usd_sgd = pd.read_excel('ExchangeRates.xlsx', sheet_name='usd-sgd')
usd_cad = pd.read_excel('ExchangeRates.xlsx', sheet_name='usd-cad')

# %% [markdown]
# ## Data explore

# %% [markdown]
# ### USD/SGD

# %%
plt.plot(usd_sgd['Date'], usd_sgd['Close'])
plt.xlabel('Date')
plt.ylabel('USD/SGD')
plt.title('USD vs SGD')
# Out:
# Text(0.5, 1.0, 'USD vs SGD')

# %%
usd_sgd.cov()
# Out:
#            Open      High       Low     Close
# Open   0.003491  0.003497  0.003472  0.003481
# High   0.003497  0.003513  0.003480  0.003497
# Low    0.003472  0.003480  0.003460  0.003471
# Close  0.003481  0.003497  0.003471  0.003489

# %% [markdown]
# ### USD/JPY

# %%
plt.plot(usd_jpy['Date'], usd_jpy['Close'])
plt.xlabel('Date')
plt.ylabel('USD/JPY')
plt.title('USD vs JPY')
# Out:
# Text(0.5, 1.0, 'USD vs JPY')

# %%
usd_jpy.cov()
# Out:
#              Open        High         Low       Close
# Open   176.103488  176.404959  175.619502  176.073606
# High   176.404959  176.859853  175.966489  176.538851
# Low    175.619502  175.966489  175.335034  175.771171
# Close  176.073606  176.538851  175.771171  176.360172

# %% [markdown]
# ### USD/CAD

# %%
plt.plot(usd_cad['Date'], usd_cad['Close'])
plt.xlabel('Date')
plt.ylabel('USD/CAD')
plt.title('USD vs CAD')
# Out:
# Text(0.5, 1.0, 'USD vs CAD')

# %%
usd_cad.cov()
# Out:
#            Open      High       Low     Close
# Open   0.019701  0.019741  0.019633  0.019680
# High   0.019741  0.019798  0.019679  0.019738
# Low    0.019633  0.019679  0.019581  0.019629
# Close  0.019680  0.019738  0.019629  0.019694

# %% [markdown]
# ### USD/GBP

# %%
plt.plot(usd_gbp['Date'], usd_gbp['Close'])
plt.xlabel('Date')
plt.ylabel('USD/GBP')
plt.title('USD vs GBP')
# Out:
# Text(0.5, 1.0, 'USD vs GBP')

# %%
usd_gbp.cov()
# Out:
#            Open      High       Low     Close
# Open   0.004768  0.004800  0.004727  0.004760
# High   0.004800  0.004842  0.004761  0.004801
# Low    0.004727  0.004761  0.004692  0.004726
# Close  0.004760  0.004801  0.004726  0.004767
